# %%
import matplotlib.pyplot as plt
import numpy as np
import unet
from unet import utils
from unet.datasets import circles

# %%
train_dataset, validation_dataset = circles.load_data(100, nx=200, ny=200, splits=(0.7, 0.3))
# Out:
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9c5dfc24ec0c> in <module>
# ----> 1 val = train_dataset.take(1).numpy()
#       2 val
#
# AttributeError: 'TakeDataset' object has no attribute 'numpy'

# %%
# unet_model = unet.build_model(channels=circles.channels,
#                               num_classes=circles.classes,
#                               layer_depth=3,
#                               filters_root=16)
# unet.finalize_model(unet_model)

# %%
# Out:
# <TensorSliceDataset shapes: ((200, 200, 1), (200, 200, 2)), types: (tf.float64, tf.float64)>

# %%
trainer = unet.Trainer(checkpoint_callback=False)
trainer.fit(unet_model,
            train_dataset,
            validation_dataset,
            epochs=5,
            batch_size=1)
# Out:
# Epoch 1/5
# 70/70 [==============================] - 18s 245ms/step - loss: 0.5437 - categorical_crossentropy: 0.5437 - categorical_accuracy: 0.7781 - mean_iou: 0.3332 - dice_coefficient: 0.6336 - auc: 0.7970 - val_loss: 0.1353 - val_categorical_crossentropy: 0.1353 - val_categorical_accuracy: 0.9534 - val_mean_iou: 0.5056 - val_dice_coefficient: 0.9080 - val_auc: 0.9913
# Epoch 2/5
# 70/70 [==============================] - 17s 239ms/step - loss: 0.1639 - categorical_crossentropy: 0.1639 - categorical_accuracy: 0.9515 - mean_iou: 0.5269 - dice_coefficient: 0.9149 - auc: 0.9845 - val_loss: 0.0925 - val_categorical_crossentropy: 0.0925 - val_categorical_accuracy: 0.9534 - val_mean_iou: 0.6297 - val_dice_coefficient: 0.9548 - val_auc: 0.9922
# Epoch 3/5
# 70/70 [==============================] - 17s 242ms/step - loss: 0.1370 - categorical_crossentropy: 0.1370 - categorical_accuracy: 0.9518 - mean_iou: 0.5685 - dice_coefficient: 0.9288 - auc: 0.9878 - val_loss: 0.0908 - val_categorical_crossentropy: 0.0908 - val_categorical_accuracy: 0.9534 - val_mean_iou: 0.6471 - val_dice_coefficient: 0.9637 - val_auc: 0.9922
# Epoch 4/5
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1139 - categorical_crossentropy: 0.1139 - categorical_accuracy: 0.9634 - mean_iou: 0.6120 - dice_coefficient: 0.9459 - auc: 0.9914 - val_loss: 0.0688 - val_categorical_crossentropy: 0.0688 - val_categorical_accuracy: 0.9785 - val_mean_iou: 0.7320 - val_dice_coefficient: 0.9634 - val_auc: 0.9953
# Epoch 5/5
# 70/70 [==============================] - 17s 240ms/step - loss: 0.0935 - categorical_crossentropy: 0.0935 - categorical_accuracy: 0.9765 - mean_iou: 0.6949 - dice_coefficient: 0.9572 - auc: 0.9927 - val_loss: 0.0634 - val_categorical_crossentropy: 0.0634 - val_categorical_accuracy: 0.9823 - val_mean_iou: 0.7643 - val_dice_coefficient: 0.9689 - val_auc: 0.9953

# %%
#prediction = unet_model.predict(validation_dataset.batch(batch_size=3))
prediction
# Out:
# array([[[[9.9935716e-01, 6.4283866e-04],
#          [9.9945050e-01, 5.4944691e-04],
#          [9.9950266e-01, 4.9728027e-04],
#          ...,
#          [9.9910164e-01, 8.9839724e-04],
#          [9.9899942e-01, 1.0006040e-03],
#          [9.9908304e-01, 9.1695081e-04]],
#
#         [[9.9937832e-01, 6.2170532e-04],
#          [9.9948478e-01, 5.1521679e-04],
#          [9.9951255e-01, 4.8744620e-04],
#          ...,
#          [9.9917161e-01, 8.2839991e-04],
#          [9.9908423e-01, 9.1577909e-04],
#          [9.9918753e-01, 8.1245834e-04]],
#
#         [[9.9940753e-01, 5.9244619e-04],
#          [9.9948287e-01, 5.1712681e-04],
#          [9.9951208e-01, 4.8795503e-04],
#          ...,
#          [9.9910849e-01, 8.9152681e-04],
#          [9.9905056e-01, 9.4943418e-04],
#          [9.9914289e-01, 8.5705169e-04]],
#
#         ...,
#
#         [[9.9922597e-01, 7.7398063e-04],
#          [9.9932265e-01, 6.7736820e-04],
#          [9.9934775e-01, 6.5225927e-04],
#          ...,
#          [9.9939442e-01, 6.0559303e-04],
#          [9.9930835e-01, 6.9166976e-04],
#          [9.9932635e-01, 6.7363365e-04]],
#
#         [[9.9926203e-01, 7.3790090e-04],
#          [9.9930763e-01, 6.9235591e-04],
#          [9.9929810e-01, 7.0183648e-04],
#          ...,
#          [9.9942660e-01, 5.7344802e-04],
#          [9.9936217e-01, 6.3780881e-04],
#          [9.9934846e-01, 6.5157155e-04]],
#
#         [[9.9928743e-01, 7.1262795e-04],
#          [9.9933809e-01, 6.6183426e-04],
#          [9.9929023e-01, 7.0971530e-04],
#          ...,
#          [9.9950838e-01, 4.9165252e-04],
#          [9.9945635e-01, 5.4362533e-04],
#          [9.9946386e-01, 5.3620484e-04]]],
#
#
#        [[[9.9805355e-01, 1.9464421e-03],
#          [9.9797839e-01, 2.0216415e-03],
#          [9.9778098e-01, 2.2190625e-03],
#          ...,
#          [9.9823183e-01, 1.7682263e-03],
#          [9.9830675e-01, 1.6931929e-03],
#          [9.9838316e-01, 1.6168000e-03]],
#
#         [[9.9786621e-01, 2.1338207e-03],
#          [9.9795854e-01, 2.0413974e-03],
#          [9.9787164e-01, 2.1283764e-03],
#          ...,
#          [9.9835986e-01, 1.6400915e-03],
#          [9.9839264e-01, 1.6072837e-03],
#          [9.9852729e-01, 1.4726395e-03]],
#
#         [[9.9774158e-01, 2.2584004e-03],
#          [9.9804366e-01, 1.9563474e-03],
#          [9.9819118e-01, 1.8088287e-03],
#          ...,
#          [9.9847609e-01, 1.5239279e-03],
#          [9.9854940e-01, 1.4505471e-03],
#          [9.9857175e-01, 1.4282688e-03]],
#
#         ...,
#
#         [[9.9843174e-01, 1.5682419e-03],
#          [9.9852365e-01, 1.4763880e-03],
#          [9.9835962e-01, 1.6404018e-03],
#          ...,
#          [9.9869448e-01, 1.3055259e-03],
#          [9.9843055e-01, 1.5694520e-03],
#          [9.9840826e-01, 1.5917495e-03]],
#
#         [[9.9822015e-01, 1.7798040e-03],
#          [9.9827957e-01, 1.7203905e-03],
#          [9.9815673e-01, 1.8432541e-03],
#          ...,
#          [9.9860877e-01, 1.3913098e-03],
#          [9.9836904e-01, 1.6310068e-03],
#          [9.9830425e-01, 1.6957331e-03]],
#
#         [[9.9810326e-01, 1.8967612e-03],
#          [9.9827194e-01, 1.7280598e-03],
#          [9.9820709e-01, 1.7928940e-03],
#          ...,
#          [9.9867105e-01, 1.3289541e-03],
#          [9.9837261e-01, 1.6273855e-03],
#          [9.9833494e-01, 1.6650502e-03]]],
#
#
#        [[[9.9894220e-01, 1.0578124e-03],
#          [9.9898130e-01, 1.0187277e-03],
#          [9.9897814e-01, 1.0218511e-03],
#          ...,
#          [9.9931061e-01, 6.8940950e-04],
#          [9.9929035e-01, 7.0960069e-04],
#          [9.9933320e-01, 6.6673273e-04]],
#
#         [[9.9907351e-01, 9.2641480e-04],
#          [9.9916387e-01, 8.3619630e-04],
#          [9.9914801e-01, 8.5197663e-04],
#          ...,
#          [9.9935156e-01, 6.4846844e-04],
#          [9.9930954e-01, 6.9043384e-04],
#          [9.9939239e-01, 6.0755829e-04]],
#
#         [[9.9918598e-01, 8.1400626e-04],
#          [9.9927443e-01, 7.2555587e-04],
#          [9.9929833e-01, 7.0159178e-04],
#          ...,
#          [9.9935871e-01, 6.4123358e-04],
#          [9.9934393e-01, 6.5605075e-04],
#          [9.9942029e-01, 5.7977415e-04]],
#
#         ...,
#
#         [[9.9932778e-01, 6.7226315e-04],
#          [9.9936944e-01, 6.3057692e-04],
#          [9.9931550e-01, 6.8456074e-04],
#          ...,
#          [9.9938250e-01, 6.1753578e-04],
#          [9.9934620e-01, 6.5379002e-04],
#          [9.9936813e-01, 6.3187152e-04]],
#
#         [[9.9937773e-01, 6.2221417e-04],
#          [9.9939656e-01, 6.0337142e-04],
#          [9.9936527e-01, 6.3473586e-04],
#          ...,
#          [9.9927360e-01, 7.2642555e-04],
#          [9.9923384e-01, 7.6620484e-04],
#          [9.9925262e-01, 7.4731722e-04]],
#
#         [[9.9938810e-01, 6.1187631e-04],
#          [9.9941671e-01, 5.8330712e-04],
#          [9.9935442e-01, 6.4554065e-04],
#          ...,
#          [9.9923003e-01, 7.6992874e-04],
#          [9.9914598e-01, 8.5400417e-04],
#          [9.9920648e-01, 7.9355977e-04]]],
#
#
#        ...,
#
#
#        [[[9.9863940e-01, 1.3606059e-03],
#          [9.9870920e-01, 1.2907776e-03],
#          [9.9868137e-01, 1.3185837e-03],
#          ...,
#          [9.9913639e-01, 8.6362055e-04],
#          [9.9912781e-01, 8.7224372e-04],
#          [9.9924099e-01, 7.5906597e-04]],
#
#         [[9.9879706e-01, 1.2029732e-03],
#          [9.9894708e-01, 1.0529024e-03],
#          [9.9888176e-01, 1.1182401e-03],
#          ...,
#          [9.9916112e-01, 8.3885295e-04],
#          [9.9907815e-01, 9.2184852e-04],
#          [9.9920636e-01, 7.9368532e-04]],
#
#         [[9.9889058e-01, 1.1093878e-03],
#          [9.9898118e-01, 1.0188358e-03],
#          [9.9894649e-01, 1.0535853e-03],
#          ...,
#          [9.9904639e-01, 9.5359038e-04],
#          [9.9896550e-01, 1.0344415e-03],
#          [9.9906200e-01, 9.3802891e-04]],
#
#         ...,
#
#         [[9.9779236e-01, 2.2076671e-03],
#          [9.9816388e-01, 1.8361940e-03],
#          [9.9829561e-01, 1.7043799e-03],
#          ...,
#          [9.9856204e-01, 1.4380224e-03],
#          [9.9859601e-01, 1.4040233e-03],
#          [9.9892479e-01, 1.0752202e-03]],
#
#         [[9.9799287e-01, 2.0070958e-03],
#          [9.9838173e-01, 1.6183041e-03],
#          [9.9850672e-01, 1.4932987e-03],
#          ...,
#          [9.9844873e-01, 1.5512635e-03],
#          [9.9855512e-01, 1.4449147e-03],
#          [9.9887568e-01, 1.1243573e-03]],
#
#         [[9.9835157e-01, 1.6485011e-03],
#          [9.9870813e-01, 1.2919116e-03],
#          [9.9873263e-01, 1.2673450e-03],
#          ...,
#          [9.9849594e-01, 1.5040676e-03],
#          [9.9854136e-01, 1.4586457e-03],
#          [9.9886096e-01, 1.1391102e-03]]],
#
#
#        [[[9.9933320e-01, 6.6671183e-04],
#          [9.9928397e-01, 7.1607577e-04],
#          [9.9917811e-01, 8.2191668e-04],
#          ...,
#          [9.9907076e-01, 9.2916266e-04],
#          [9.9900913e-01, 9.9087181e-04],
#          [9.9918479e-01, 8.1515074e-04]],
#
#         [[9.9930358e-01, 6.9638126e-04],
#          [9.9924242e-01, 7.5759029e-04],
#          [9.9908936e-01, 9.1068499e-04],
#          ...,
#          [9.9907047e-01, 9.2959800e-04],
#          [9.9896216e-01, 1.0378531e-03],
#          [9.9916303e-01, 8.3700579e-04]],
#
#         [[9.9927932e-01, 7.2071538e-04],
#          [9.9918240e-01, 8.1763050e-04],
#          [9.9905103e-01, 9.4892684e-04],
#          ...,
#          [9.9902666e-01, 9.7338291e-04],
#          [9.9892324e-01, 1.0767048e-03],
#          [9.9905831e-01, 9.4175874e-04]],
#
#         ...,
#
#         [[9.9920839e-01, 7.9159945e-04],
#          [9.9924695e-01, 7.5305352e-04],
#          [9.9917430e-01, 8.2570314e-04],
#          ...,
#          [9.9929976e-01, 7.0027390e-04],
#          [9.9922299e-01, 7.7695347e-04],
#          [9.9925619e-01, 7.4377371e-04]],
#
#         [[9.9918586e-01, 8.1410131e-04],
#          [9.9923158e-01, 7.6837494e-04],
#          [9.9922943e-01, 7.7060529e-04],
#          ...,
#          [9.9930930e-01, 6.9073797e-04],
#          [9.9925679e-01, 7.4323913e-04],
#          [9.9921417e-01, 7.8585919e-04]],
#
#         [[9.9917370e-01, 8.2622527e-04],
#          [9.9926072e-01, 7.3923147e-04],
#          [9.9925548e-01, 7.4453931e-04],
#          ...,
#          [9.9934000e-01, 6.6002022e-04],
#          [9.9927264e-01, 7.2735932e-04],
#          [9.9923658e-01, 7.6343596e-04]]],
#
#
#        [[[9.9726045e-01, 2.7395724e-03],
#          [9.9726909e-01, 2.7309109e-03],
#          [9.9738318e-01, 2.6168120e-03],
#          ...,
#          [9.9776757e-01, 2.2324626e-03],
#          [9.9778950e-01, 2.2104585e-03],
#          [9.9795651e-01, 2.0434998e-03]],
#
#         [[9.9758172e-01, 2.4182366e-03],
#          [9.9772674e-01, 2.2733235e-03],
#          [9.9762303e-01, 2.3769960e-03],
#          ...,
#          [9.9787891e-01, 2.1211253e-03],
#          [9.9781054e-01, 2.1894376e-03],
#          [9.9804425e-01, 1.9557329e-03]],
#
#         [[9.9782676e-01, 2.1732023e-03],
#          [9.9788409e-01, 2.1158615e-03],
#          [9.9770433e-01, 2.2956708e-03],
#          ...,
#          [9.9776733e-01, 2.2326738e-03],
#          [9.9779522e-01, 2.2048436e-03],
#          [9.9799037e-01, 2.0096726e-03]],
#
#         ...,
#
#         [[9.9823159e-01, 1.7684224e-03],
#          [9.9826497e-01, 1.7350245e-03],
#          [9.9819118e-01, 1.8088114e-03],
#          ...,
#          [9.9833161e-01, 1.6684645e-03],
#          [9.9806529e-01, 1.9346725e-03],
#          [9.9822015e-01, 1.7798777e-03]],
#
#         [[9.9823219e-01, 1.7678426e-03],
#          [9.9819934e-01, 1.8006088e-03],
#          [9.9813473e-01, 1.8651915e-03],
#          ...,
#          [9.9833518e-01, 1.6648560e-03],
#          [9.9795628e-01, 2.0436798e-03],
#          [9.9803513e-01, 1.9648361e-03]],
#
#         [[9.9825746e-01, 1.7425033e-03],
#          [9.9830854e-01, 1.6914706e-03],
#          [9.9818867e-01, 1.8113307e-03],
#          ...,
#          [9.9856025e-01, 1.4397091e-03],
#          [9.9808288e-01, 1.9171871e-03],
#          [9.9811447e-01, 1.8855329e-03]]]], dtype=float32)

# %%
fig, ax = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(10,10))
dataset = validation_dataset.map(utils.crop_image_and_label_to_shape(prediction.shape[1:]))

for i, (image, label) in enumerate(dataset.take(3)):
    ax[i][0].matshow(image[..., -1]); ax[i][0].set_title('Original Image'); ax[i][0].axis('off')
    ax[i][1].matshow(np.argmax(label, axis=-1), cmap=plt.cm.gray); ax[i][1].set_title('Original Mask'); ax[i][1].axis('off')
    ax[i][2].matshow(np.argmax(prediction[i,...], axis=-1), cmap=plt.cm.gray); ax[i][2].set_title('Predicted Mask'); ax[i][2].axis('off')
plt.tight_layout()
