# %% [markdown]
# ### Import

# %%
import os
import numpy as np
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# ### Figure 1

# %%
X = np.zeros((3,2))
X[0,:] = [0,0]
X[1,:] = [0,2]
X[2,:] = [1,0]

# %% [markdown]
# ### Plot and Store

# %%
plt.figure(figsize=(6,6))
ax = plt.subplot(111)
ax.scatter(X[:,0],X[:,1],c='k')
plt.axis((-axvalx,axvalx,-axvaly,axvaly))

ax.spines['right'].set_linewidth(0.5)
ax.spines['top'].set_visible(0.5)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
plt.xlabel('x',fontsize=18);
plt.ylabel('y',fontsize=18);
plt.grid()
plt.savefig('../../assets/figures/regression.png')

# %% [markdown]
# ### Create Classification Data

# %%
n_samples = 200
n_features = 3
n_classes = 2
n_redundant = 0
X,y = make_classification(n_samples=n_samples, n_features=n_features,n_classes=n_classes,n_redundant=n_redundant)
class_ind0 = np.where(y==0)[0]
class_ind1 = np.where(y==1)[0]
axval = np.abs(np.round(np.min(X)))

# %% [markdown]
# ### Plot and Store

# %%
plt.figure(figsize=(6,6))
ax = plt.subplot(111)
ax.scatter(X[class_ind0,0],X[class_ind0,1],c='k')
ax.scatter(X[class_ind1,0],X[class_ind1,1],c='r')
plt.axis((-axval,axval,-axval,axval))
ax.spines['right'].set_linewidth(0.5)
ax.spines['top'].set_visible(0.5)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
plt.xlabel('x',fontsize=18);
plt.ylabel('y',fontsize=18);
plt.grid()
plt.savefig('../../assets/figures/classification.png')

# %% [markdown]
# ### Clustering Data

# %%
n_samples = 200
n_features = 2
no_clusters = 4
n_redundant = 0
X,y = make_blobs(n_samples=n_samples, n_features=n_features, centers=no_clusters)
class_ind0 = np.where(y==0)[0]
class_ind1 = np.where(y==1)[0]
class_ind2 = np.where(y==2)[0]
class_ind3 = np.where(y==3)[0]
axval = np.abs(np.round(np.min(X))) * 1.1

# %% [markdown]
# ### Plot and Store

# %%
plt.figure(figsize=(6,6))
ax = plt.subplot(111)
ax.scatter(X[class_ind0,0],X[class_ind0,1],c='k')
ax.scatter(X[class_ind1,0],X[class_ind1,1],c='r')
ax.scatter(X[class_ind2,0],X[class_ind2,1],c='g')
ax.scatter(X[class_ind3,0],X[class_ind3,1],c='m')
plt.axis((-axval,axval,-axval,axval));
ax.spines['right'].set_linewidth(0.5)
ax.spines['top'].set_visible(0.5)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
plt.xlabel('x',fontsize=18);
plt.ylabel('y',fontsize=18);
plt.grid()
plt.savefig('../../assets/figures/clustering.png')
