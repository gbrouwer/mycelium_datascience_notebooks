# %% [markdown]
# ### Import

# %%
import os
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.spatial.distance import cdist
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
from scipy.stats import multivariate_normal as mnorm
from mpl_toolkits import mplot3d
from matplotlib import font_manager as fm, rcParams
from mpl_toolkits import mplot3d
from sklearn.datasets import make_blobs
from sklearn.datasets import make_classification
from sklearn.datasets import make_regression

# %% [markdown]
# ### Fonts

# %%
csfont = {'fontname':'Georgia'}
hfont = {'fontname':'Helvetica'}

# %% [markdown]
# ### Parameters

# %%
no_samples = 1000
no_features = 3
no_informative = no_features
no_redundant = 0
no_repeated = 0
no_classes = 2
class_sep = 2.0
scale = 1.0
no_clusters_per_class = 1

# %% [markdown]
# ### Create Regression Data

# %%
X, Y, coef = make_regression(
    n_samples = no_samples,
    n_features = no_features, 
    n_informative = no_informative, 
    noise = 0.1,
    bias = 1.0,
    coef = True,
    random_state=20)
Y = Y - np.min(Y)
Y = Y / np.max(Y) * 255
Y = Y.astype(int)
cmap = plt.get_cmap('magma')
cmap = np.array(cmap.colors)
colors = np.ones((1000,4))
colors[:,:3] = cmap[Y,:]

# %% [markdown]
# ### Plot Regression Data

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.scatter(X[:,0] * 1.00,
           X[:,1] * 0.25,
           X[:,2] * 0.25,s=50,c=colors)
ax.view_init(elev=40., azim=60)
ax.set_xticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_yticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_zticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_ylabel('\nX',fontsize=18,**csfont)
ax.set_xlabel('\nY',fontsize=18,**csfont)
ax.set_zlabel('Z',fontsize=18,**csfont);
plt.savefig('../../assets/figures/012/012_data_space_geometry_regression.png',dpi=300,bbox_inches="tight")

# %% [markdown]
# ### Create Classification Data

# %%
X, Y, = make_classification(
    n_samples = no_samples,
    n_features= no_features, 
    n_classes= no_classes,
    class_sep = class_sep,
    n_redundant = no_redundant, 
    n_informative= no_informative, 
    n_clusters_per_class = no_clusters_per_class,
    random_state=20)
X[:,0] = X[:,0] - 2
X[:,2] = X[:,2] - 2
X = X * 0.65
cmap = plt.get_cmap('magma')
cmap = np.array(cmap.colors)
cmap = cmap[[40,160],:]
colors = np.ones((1000,4))
colors[:,:3] = cmap[Y,:]

# %% [markdown]
# ### Plot Classification Data

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.scatter(X[:,0],
           X[:,1],
           X[:,2],s=50,c=colors)
ax.view_init(elev=40., azim=60)
ax.set_xticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_yticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_zticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_ylabel('\nX',fontsize=18,**csfont)
ax.set_xlabel('\nY',fontsize=18,**csfont)
ax.set_zlabel('Z',fontsize=18,**csfont);
plt.savefig('../../assets/figures/012/012_data_space_geometry_classification.png',dpi=300,bbox_inches="tight")

# %% [markdown]
# ### Create Clustering Data

# %%
X, Y, centers = make_blobs(
    n_samples = no_samples,
    n_features= no_features,
    centers = 4,
    cluster_std = 1.0,
    return_centers = True,
    random_state=40)
X[:,0] = X[:,0] - np.mean(X[:,0])
X[:,1] = X[:,1] - np.mean(X[:,1])
X[:,2] = X[:,2] - np.mean(X[:,2])
X[:,0] = X[:,0] * 0.5
X[:,1] = X[:,1] * 0.25
X[:,2] = X[:,2] * 0.4
Y = Y.astype(int)
cmap = plt.get_cmap('magma')
cmap = np.array(cmap.colors)
cmap = cmap[[60,120,180,240],:]
colors = np.ones((1000,4))
colors[:,:3] = cmap[Y,:]

# %% [markdown]
# ### Plot

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.scatter(X[:,0],
           X[:,1],
           X[:,2],s=50,c=colors)
ax.view_init(elev=40., azim=60)
ax.set_xticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_yticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_zticks(np.linspace(-3,3,7),labels=np.linspace(-3,3,7),fontsize=14,**csfont);
ax.set_ylabel('\nX',fontsize=18,**csfont)
ax.set_xlabel('\nY',fontsize=18,**csfont)
ax.set_zlabel('Z',fontsize=18,**csfont);
plt.savefig('../../assets/figures/012/012_data_space_geometry_clustering.png',dpi=300,bbox_inches="tight")
