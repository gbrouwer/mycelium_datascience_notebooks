# %% [markdown]
# ### Import

# %%
import os
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
from scipy.spatial.distance import cdist
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
from scipy.stats import multivariate_normal as mnorm
from mpl_toolkits import mplot3d
from matplotlib import font_manager as fm, rcParams

# %% [markdown]
# ### Fonts

# %%
csfont = {'fontname':'Georgia'}
hfont = {'fontname':'Helvetica'}

# %% [markdown]
# ### Create Two Models, but only one with an offset

# %%
a1 = 1
b1 = 0
a2 = 1
b2 = 2
rvx = mnorm(0,0.2)
x1 = rvx.rvs(500)
x2 = rvx.rvs(500)
n1 = rvx.rvs(500)
n2 = rvx.rvs(500)
y1 = ((a1 * x1) + b1) + n1
y2 = ((a2 * x2) + b2) + n2

# %% [markdown]
# ### Plot

# %%
plt.figure(figsize=(8,8.25))
plt.scatter(x1,y1,color=(0.2,0.6,0.3))
plt.scatter(x2,y2,color=(0.9,0.3,0.6))
plt.plot([-1.5,1.5],[-1.5*a1 + b1,1.5*a1 + b1,],c=(0.2,0.5,0.3),linewidth=4,linestyle='--')
plt.plot([-1.5,1.5],[-1.5*a2 + b2,1.5*a2 + b2,],c=(0.8,0.2,0.5),linewidth=4,linestyle='--')
plt.axis((-2,2,-3,4))
plt.grid()
plt.xlabel('variable x',fontsize=22,**csfont);
plt.ylabel('variable y',fontsize=22,**csfont);
txt = plt.text(-1.5,0.0,'y = x',c=(0,0,0),rotation=0,fontsize=32,**csfont);
txt = plt.text(-1.5,-2.0,'y = x + 1',c=(0,0,0),rotation=0,fontsize=32,**csfont);
plt.xticks(fontsize=14,**csfont);
plt.yticks(fontsize=14,**csfont);
plt.savefig('../../assets/figures/012/012_bias_offset_intercept.png',dpi=300,bbox_inches="tight");
