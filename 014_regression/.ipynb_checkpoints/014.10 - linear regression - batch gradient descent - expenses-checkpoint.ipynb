# %% [markdown]
# ### Import

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Load Data

# %%
data = pd.read_csv('../../data/healthcare_cost/insurance.csv')
columns = data.columns
x_raw = data.iloc[:,0].values
y_raw = data.iloc[:,-1].values

# %% [markdown]
# ### Clean Dataset for the univariate example

# %%
ind0 = np.where(y_raw > 17000)[0]
ind1 = np.where(x_raw < 46)[0]
ind2 = np.where(y_raw > 10000)[0]
ind3 = np.intersect1d(ind1,ind2)
ind4 = np.union1d(ind3,ind0)
ind5 = range(x_raw.shape[0])
ind5 = np.setdiff1d(ind5,ind4)
x = x_raw[ind5].astype('float').copy()
y = y_raw[ind5].astype('float').copy()

# %% [markdown]
# ### Normalize

# %%
mean_x = np.mean(x)
mean_y = np.mean(y)
x_norm = x / mean_x
y_norm = y / mean_y

# %% [markdown]
# ### Add Column of ones

# %%
x_norm = np.expand_dims(x_norm,-1)
o = np.ones((x_norm.shape[0],1))
X_norm = np.hstack((x_norm,o))

# %% [markdown]
# ### Divide Data

# %%
X_train = X_norm[:600,:].copy()
X_test = X_norm[600:,:].copy()
y_train = y_norm[:600].copy()
y_test = y_norm[600:].copy()

# %% [markdown]
# ### Init

# %%
learning_rate = 0.01
w = np.random.randn((2))
w = np.array([2,2])
batch_size = 50
no_epoch = 1000

# %% [markdown]
# ### Gradient Descent

# %%
w_history = []
loss_history = []
for epoch in range(no_epoch):
    
    randval = np.random.permutation(X_train.shape[0])
    X_batch = X_train[:batch_size,:]
    y_batch = y_train[:batch_size]

    y_pred = np.dot(X_batch,w)
    E = (y_batch - y_pred)
    loss = np.sum(E**2)
    loss_history.append(loss)
    w_history.append(w)

    delta = np.dot(X_batch.T,E) * (-2/X_batch.shape[0])
    delta = delta * learning_rate
    w = w - delta
loss_history = np.array(loss_history)

# %% [markdown]
# ### Plot Loss

# %%
plt.figure(figsize=(6,6));
plt.plot(loss_history)
plt.grid();
plt.xlabel('Epoch',fontsize=18);
plt.ylabel('Loss',fontsize=18);

# %% [markdown]
# ### Create Regression Line

# %%
x0 = 0.25
x1 = 1.75
y0 = w[0]*x0 + w[1]
y1 = w[0]*x1 + w[1]

# %% [markdown]
# ### Plot

# %%
plt.figure(figsize=(6,6));
plt.scatter(X_train[:,0],y_train);
plt.plot([x0,x1],[y0,y1],'k',zorder=100);
plt.grid();
plt.xlabel('Age (normalized)',fontsize=18);
plt.ylabel('Medical Expenses (normalized)',fontsize=18);

# %% [markdown]
# ### Plot Loss Field

# %%
aval = np.linspace(-2,2,21)
bval = np.linspace(-2,2,21)
Xm,Ym = np.meshgrid(aval, bval)
XX = np.array([Xm.ravel(), Ym.ravel()]).T
w_history = np.array(w_history)
loss_history = np.array(loss_history)
lossfield = np.zeros((21,21)).T
for i in range(len(aval)):
    for j in range(len(bval)):
        w = np.array([aval[i],bval[j]])
        w = np.expand_dims(w,-1)
        y_pred = np.dot(X_batch,w)
        E = (y_batch - y_pred)
        loss = np.sum(E**2) / X_batch.shape[0]
        lossfield[j,i] = loss
print(loss)
plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.plot_surface(Xm,Ym,lossfield,cmap='YlGnBu', edgecolor='gray')
ax.set_title('Surface plot')
ax.view_init(elev=30., azim=310)
ax.plot(w_history[:,0],w_history[:,1],loss_history,zorder=100,c='k')
plt.axis((-2,2,-2,2))
plt.savefig('../../assets/figures/test.png');
plt.show();    
# print(np.min(loss_history))
# print(np.min(lossfield))
# Out:
# 472.35986786960325

# %% [markdown]
# ### Undo Normalization and create regression line

# %%
X_orig = X_train * mean_x
y_orig = y_train * mean_y
x0 = 0.25
x1 = 1.75
y0 = w[0]*x0 + w[1]
y1 = w[0]*x1 + w[1]
x0 = x0 * mean_x
x1 = x1 * mean_x
y0 = y0 * mean_y
y1 = y1 * mean_y

# %% [markdown]
# ### Plot

# %%
lossfield
# Out:
# array([[9325053.96139782, 8582054.31333004, 7871682.99796458,
#         7193940.01530143, 6548825.36534059, 5936339.04808208,
#         5356481.06352587, 4809251.41167199, 4294650.09252041,
#         3812677.10607116, 3363332.45232422, 2946616.13127959,
#         2562528.14293729, 2211068.48729729, 1892237.16435961,
#         1606034.17412425, 1352459.5165912 , 1131513.19176047,
#          943195.19963205,  787505.54020595,  664444.21348216],
#        [8618531.86686002, 7904353.79154245, 7222804.0489272 ,
#         6573882.63901426, 5957589.56180364, 5373924.81729533,
#         4822888.40548933, 4304480.32638566, 3818700.5799843 ,
#         3365549.16628525, 2945026.08528852, 2557131.33699411,
#         2201864.92140201, 1879226.83851222, 1589217.08832475,
#         1331835.6708396 , 1107082.58605676,  914957.83397624,
#          755461.41459803,  628593.32792214,  534353.57394856],
#        [7940809.77232222, 7255453.26975486, 6602725.09988982,
#         5982625.26272709, 5395153.75826668, 4840310.58650858,
#         4318095.7474528 , 3828509.24109933, 3371551.06744818,
#         2947221.22649934, 2555519.71825282, 2196446.54270862,
#         1870001.69986673, 1576185.18972716, 1314997.0122899 ,
#         1086437.16755495,  890505.65552233,  727202.47619201,
#          596527.62956402,  498481.11563834,  433062.93441497],
#        [7291887.67778442, 6635352.74796727, 6011446.15085244,
#         5420167.88643992, 4861517.95472972, 4335496.35572183,
#         3842103.08941626, 3381338.155813  , 2953201.55491206,
#         2557693.28671344, 2194813.35121713, 1864561.74842313,
#         1566938.47833145, 1301943.54094209, 1069576.93625504,
#          869838.66427031,  702728.72498789,  568247.11840779,
#          466393.84453   ,  397168.90335453,  360572.29488137],
#        [6671765.58324662, 6044052.22617968, 5448967.20181506,
#         4886510.51015275, 4356682.15119276, 3859482.12493508,
#         3394910.43137972, 2962967.07052667, 2563652.04237594,
#         2196965.34692753, 1862906.98418143, 1561476.95413764,
#         1292675.25679618, 1056501.89215702,  852956.86022018,
#          682040.16098566,  543751.79445345,  438091.76062356,
#          365060.05949599,  324656.69107072,  316881.65534778],
#        [6080443.48870882, 5481551.70439209, 4915288.25277768,
#         4381653.13386558, 3880646.3476558 , 3412267.89414833,
#         2976517.77334318, 2573395.98524034, 2202902.52983982,
