# %%
from luna.pretrained_models import models
from luna.featurevis import featurevis, images, image_reader
from luna.featurevis.transformations import *
import matplotlib.pyplot as plt

model = models.model_inceptionv3()

# %%
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_94 (Conv2D)             (None, None, None,   864         ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_94 (BatchN  (None, None, None,   96         ['conv2d_94[0][0]']
#  ormalization)                  32)
#
#  activation_94 (Activation)     (None, None, None,   0           ['batch_normalization_94[0][0]']
#                                 32)
#
#  conv2d_95 (Conv2D)             (None, None, None,   9216        ['activation_94[0][0]']
#                                 32)
#
#  batch_normalization_95 (BatchN  (None, None, None,   96         ['conv2d_95[0][0]']
#  ormalization)                  32)
#
# ...

# %%
model.trainable = False
image = images.initialize_image(324, 324)
iterations = 2048
learning_rate = 0.7

optimizer = tf.keras.optimizers.Adam(epsilon=1e-08, learning_rate=0.05)

# # Define a function containing all the transformations that you would like to apply
# # At the moment scaling and blur yield the best results.
# Nonetheless, all other lucid transformations are implemented in featurevis.transformations and can be added too.
def my_trans(img):
    img = scale_values(img)
    img = blur(img)
    return img

opt_param = featurevis.OptimizationParameters(iterations, learning_rate, optimizer=optimizer)
activation, image= featurevis.visualize_filter(image, model, "mixed6", 30, opt_param, transformation=my_trans)

plt.imshow(image)
plt.savefig("image.svg")
plt.clf()

images.save_image(image, name="test")
image_reader.save_npy_as_png("test.npy", ".")
# Out:
# Help on module luna.featurevis.image_reader in luna.featurevis:
#
# NAME
#     luna.featurevis.image_reader
#
# DESCRIPTION
#     A utility file that takes all numpy arrays in the input folder and saves
#     them as pngs in the output folder
#
# FUNCTIONS
#     save_npy_as_png(input_path, output_path)
#         Saves a numpy image as a png given an image path.
#
#         Args:
#             path (string): the path to the numpy file containing the image data.
#
# FILE
#     /Users/brouwerg/.pyenv/versions/3.9.6/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/luna/featurevis/image_reader.py
#
#
# initializing image
# Starting Feature Vis Process
# >> 99 %
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# >> 100 %

# %%
plt.imshow(image)
plt.savefig("image.svg")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
