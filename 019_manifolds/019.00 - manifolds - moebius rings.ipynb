# %% [markdown]
# ### Import

# %%
import os
import numpy as np
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import spectral.io.aviris as aviris
import colour
from PIL import Image
from scipy.stats import multivariate_normal as mnorm
from scipy import ndimage
from matplotlib import cm
from mpl_toolkits import mplot3d
from skimage import io, color
from matplotlib.collections import PatchCollection
from matplotlib.patches import Rectangle
from matplotlib.tri import Triangulation

# %% [markdown]
# ### Fonts

# %%
csfont = {'fontname':'Georgia'}
hfont = {'fontname':'Helvetica'}

# %% [markdown]
# ###   Moebius Strip

# %%
plt.figure(figsize=(12,12))
theta = np.linspace(0, 2 *np.pi, 40)
w = np.linspace(-0.25, 0.25, 6)
w, theta = np.meshgrid(w, theta)
phi = 0.5 * theta
r = 1 + w * np.cos(phi)
x = np.ravel(r * np.cos(theta))
y = np.ravel(r * np.sin(theta))
z = np.ravel(w * np.sin(phi))
tri = Triangulation(np.ravel(w), np.ravel(theta))
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, 
                cmap='Spectral',alpha=1.0,
                edgecolor='k',linewidth=0.5)
ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_zlim(-1, 1);
ax.set_yticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5)[::-1],fontsize=14,**csfont);
ax.set_xticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5),fontsize=14,**csfont);
ax.set_zticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5),fontsize=14,**csfont);
ax.axis('off');
for i in range(1):
    ax.view_init(elev=30., azim=i);
    plt.savefig('../../assets/figures/019/moebius_1/' + str(i) + '.png',bbox_inches="tight")

# %% [markdown]
# ### Alternative 1

# %%
plt.figure(figsize=(12,12))
theta = np.linspace(0, 2 *np.pi, 60)
w = np.linspace(-0.25, 0.25, 12)
w, theta = np.meshgrid(w, theta)
phi = 0.5 * theta
r = 1 + w * np.cos(phi)
x = np.ravel(r * np.cos(theta))
y = np.ravel(r * np.sin(theta))
z = np.ravel(w * np.sin(phi))
tri = Triangulation(np.ravel(w), np.ravel(theta))
ax = plt.axes(projection='3d')
ax.tricontourf(x, y, z, triangles=tri.triangles, 
                cmap='Spectral',alpha=1.0)
ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_zlim(-1, 1);
ax.set_yticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5)[::-1],fontsize=14,**csfont);
ax.set_xticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5),fontsize=14,**csfont);
ax.set_zticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5),fontsize=14,**csfont);
ax.axis('off');
for i in range(360):
    ax.view_init(elev=30., azim=i);
    plt.savefig('../../assets/figures/019/moebius_2/' + str(i) + '.png',bbox_inches="tight")

# %% [markdown]
# ### Alternative 2

# %%
plt.figure(figsize=(12,12))
theta = np.linspace(0, 2 *np.pi, 60)
w = np.linspace(-0.25, 0.25, 12)
w, theta = np.meshgrid(w, theta)
phi = 0.5 * theta
r = 1 + w * np.cos(phi)
x = np.ravel(r * np.cos(theta))
y = np.ravel(r * np.sin(theta))
z = np.ravel(w * np.sin(phi))
tri = Triangulation(np.ravel(w), np.ravel(theta))
ax = plt.axes(projection='3d')
ax.tricontour(x, y, z, triangles=tri.triangles, 
                cmap='Spectral',alpha=1.0)
ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_zlim(-1, 1);
ax.set_yticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5)[::-1],fontsize=14,**csfont);
ax.set_xticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5),fontsize=14,**csfont);
ax.set_zticks(np.linspace(-1,1,5),labels=np.linspace(-1,1,5),fontsize=14,**csfont);
ax.axis('off');
for i in range(360):
    ax.view_init(elev=30., azim=i);
    plt.savefig('../../assets/figures/019/moebius_3/' + str(i) + '.png',bbox_inches="tight")
