# %% [markdown]
# # Gini Impurity Computation Example

# %% [markdown]
# ### Import

# %%
import os
import numpy as np
import sys
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as mnorm
from matplotlib.colors import LogNorm
from sklearn import mixture
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Create two distributions that are separated along one dimension only
# To demonstrate how to compute the gini impurity and use it to find the best split, we first create an artificial data set. The dataset has two classes and two features, one of which shows a clear shift between the the classes, the other does not.

# %%
mu_1 = np.array([+1,0])
mu_2 = np.array([-1,0])
sigma_1 = np.array([[3,0],[0,10]]) * 0.25
sigma_2 = np.array([[3,0],[0,10]]) * 0.25

# %% [markdown]
# ### Create a sampling of 100 data points from each distribution and combine
# A random sampling from these two distributions gives us a well defined dataset for which one feature can be used to split the data, the other cannot.

# %%
no_points = 100
gridsize = 101
rv_1 = mnorm(mu_1,sigma_1)
rv_2 = mnorm(mu_2,sigma_2)
X1 = rv_1.rvs(no_points)
X2 = rv_2.rvs(no_points)
X = np.vstack((X1,X2))
y = np.vstack((np.zeros((100,1)),np.ones((100,1))))
# Out:
# (200, 2)

# %% [markdown]
# ### Plot Data and underlying distribution
# Notice again that splitting on feature 1 will give us high classification accuracy already, where feature 2 does not.

# %%
plt.figure(figsize=(5,5))
plt.scatter(X1[:,0],X1[:,1],c='g')
plt.scatter(X2[:,0],X2[:,1],c='r')
plt.grid()
plt.axis((-5,5,-5,5))
plt.xlabel('feature 1',fontsize=18)
plt.ylabel('feature 2',fontsize=18)
plt.savefig('../../assets/figures/15_gini_1.png');

# %% [markdown]
# ### Compute Gini Impurity
# The compute the gini impurity, we compute the probability p of each class occuring. This is easily computing as the fraction of samples labeled as each class divided. By subsequently computing the product of the probability p with (1-p) we get 0 if the probability of a class occuring is either 0 or 1. In other words, having either all or none of this particular class in the data probably makes our sample more homogenous. In the case of a binary classification, homogenous samples on both side of our splitting threshold means that most data points associated with one class are on one side of this threshold, whereas the data points of the other class are on the other side.

# %%
def compute_gini_impurity(y):

    #Compute
    gini = 0
    classes = np.unique(y)
    no_classes = len(classes)
    for i in range(no_classes):
        prob = len(np.where(classes[i] == y)[0]) / len(y)
        gini = gini + (prob * (1-prob))

    #Return
    return gini

# %% [markdown]
# ### Find Best Split
# To find the best split for a specific feature, we sort the data for that feature. We then loop through all possible way of dividing the data and compute the gini for the subset of data left and right of the current threshold.

# %%
def find_best_split(x,y):
    
    #Compute
    output = []
    classes = np.unique(y)
    no_classes = len(np.unique(y))
    indx = np.argsort(x)
    x_sorted = x[indx]
    y_sorted = y[indx]
    for i in range(len(y_sorted)-1):
        gini_left = compute_gini_impurity(y_sorted[:i+1])
        gini_right = compute_gini_impurity(y_sorted[i:])
        gini_average = (gini_left + gini_right)/no_classes
        threshold = (x_sorted[i] + x_sorted[i+1])/2
        output.append((gini_left,gini_right,gini_average,threshold))
    output = np.array(output)
    best_threshold_idx = np.argmin(output[:,2])
    best_threshold = output[best_threshold_idx,3]
    
    #Return
    return best_threshold_idx, best_threshold, output

# %% [markdown]
# ### Compute the Gini Impurity for the whole data set

# %%
current_gini = compute_gini_impurity(y)

# %% [markdown]
# ### Compute Gini Coefficients Along Both dimensions

# %%
threshold_idx1, threshold1, output1 = find_best_split(X[:,0],y[:,0])
threshold_idx2, threshold2, output2 = find_best_split(X[:,1],y[:,0])

# %% [markdown]
# ### Plot

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(output1[:,3],output1[:,0],'r');
plt.plot(output1[:,3],output1[:,1],'g');
plt.plot(output1[:,3],output1[:,2],'k');
plt.plot([threshold1,threshold1],[0,0.5],'k--');
plt.grid()
plt.axis((-4,4,0,0.6))
plt.xlabel('feature 1',fontsize=18)
plt.ylabel('impurity',fontsize=18)

plt.subplot(1,2,2)
plt.plot(output2[:,3],output2[:,0],'r');
plt.plot(output2[:,3],output2[:,1],'g');
plt.plot(output2[:,3],output2[:,2],'k');
plt.plot([threshold2,threshold2],[0,0.5],'k--');
plt.grid()
plt.axis((-4,4,0,0.6))
plt.xlabel('feature 2',fontsize=18)
plt.savefig('../../assets/figures/15_gini_2.png');
