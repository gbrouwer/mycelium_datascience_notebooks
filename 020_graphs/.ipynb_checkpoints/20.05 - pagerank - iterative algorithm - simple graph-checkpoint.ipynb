# %% [markdown]
# # 20.05 - PageRank - Edge Case 3
# Notebooks 20.03, 20.04 and 20.05 introduce the PageRank algorithm using very specific edge cases. Here, we compute PageRanks for each of 7 nodes in a very small graph.

# %% [markdown]
# ### Import

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fonts

# %%
csfont = {'fontname':'Georgia'}
hfont = {'fontname':'Helvetica'}

# %% [markdown]
# ### Define our graph to test our algorithm

# %%
graph = [
    (2,1),
    (2,3),
    (2,5),
    (2,4),
    (2,7),
    (1,2),
    (3,2),
    (3,1),
    (5,1),
    (5,3),
    (5,4),
    (4,2),
    (4,3),
    (4,5),
    (4,6),
    (6,2),
    (6,4),
    (7,4)]

# %% [markdown]
# ### Coordinates for plotting purposes

# %%
coords = np.array([
    [-1.5,-0.5],
    [-0.5,0],
    [0.75,1],
    [0.25,0.25],
    [0.25,-0.5],
    [-0.75,0.5],
    [-0.25,1]])
coords[:,0] = coords[:,0] - np.mean(coords[:,0])
coords[:,1] = coords[:,1] - np.mean(coords[:,1])

# %% [markdown]
# ### Pagerank Algorithm

# %%
def compute_pageranks(pageranks,CP,PC,d,n,nodes):

    #Run Algorithm
    for node in nodes:
        parents = CP[node]
        pagerank_sum = 0
        for parent in parents:
            pagerank = pageranks[parent-1]
            parent_outdegree = len(PC[parent])
            pagerank_sum = pagerank_sum + (pagerank/parent_outdegree)

        #Update
        pageranks[node-1] = d/n + (1-d)*pagerank_sum
    
    #Return pageranks
    return pageranks

# %% [markdown]
# ### Find the unique number of nodes

# %%
nodes = np.unique(np.array(graph))

# %% [markdown]
# ### Create two graphs where we group edges together.
# One where the key is the child node, the values are al its parents (incoming edges).<br>
# A second where we group by parent (key) and list all the outgoing edges.

# %% [markdown]
# ### Child <- Parent graph

# %%
CP = {}
for edge in graph:
    parent,child = edge
    if child not in CP:
        CP[child] = [parent]
    else:
        parents = CP[child]
        parents.append(parent)
        CP[child] = parents

# %% [markdown]
# ### Parent <- Child graph

# %%
PC = {}
for edge in graph:
    parent,child = edge
    if parent not in PC:
        PC[parent] = [child]
    else:
        children = PC[parent]
        children.append(child)
        PC[parent] = children

# %% [markdown]
# ### Init PageRank

# %%
d = 0.15
n = len(nodes)
pageranks = np.ones((n,1))

# %% [markdown]
# ### Iterate

# %%
pageranks = np.ones((n,1))
prev_pageranks = np.ones((n,1))
deltas = []
for i in range(20):
    
    #Compute new pageranks
    pageranks = compute_pageranks(pageranks,CP,PC,d,n,nodes)
    
    #Compute the delta 
    delta = np.sum((prev_pageranks - pageranks)**2) / n
    deltas.append(delta)
    
    #Assign current to previous
    prev_pageranks = pageranks.copy()

# %% [markdown]
# ### Plot the convergence

# %%
plt.figure(figsize=(7,7));
plt.plot(deltas,'k',linewidth=2);
plt.grid();
plt.xlabel('iternation',fontsize=18);
plt.ylabel('delta in pagerank',fontsize=18);

# %% [markdown]
# ### Plot the resulting PageRanks on the graph

# %%
plt.figure(figsize=(8,8))
norm_pageranks = pageranks / np.max(pageranks)
for i in range(len(nodes)):
    pr = pageranks[i,0]
    norm_pr = norm_pageranks[i,0]
    pr = np.round(pr,2)
    plt.scatter(coords[i,0],coords[i,1],s=1000,
                color=(norm_pr,0,1-(norm_pr**2)),
                zorder=100)
    plt.text(coords[i,0]-0.05,coords[i,1]-0.05,str(i+1),
             color='white',
             zorder=101,fontsize=18,**csfont)
    plt.text(coords[i,0]-0.30,coords[i,1]+0.15,str(pr),
             color='black',
             zorder=101,fontsize=18,**csfont)

plt.grid()
plt.axis((-1.5,1.5,-1.5,1.5))
for edge in graph:
    left,right = edge
    plt.plot([coords[left-1,0],coords[right-1,0]],[coords[left-1,1],coords[right-1,1]],'k')
plt.xlabel('x',fontsize=18,**csfont);
plt.ylabel('y',fontsize=18,**csfont);
plt.xticks(fontsize=14,**csfont);
plt.yticks(fontsize=14,**csfont);
plt.savefig('../../assets/figures/020/pagerank_3.png',dpi=300,bbox_inches="tight")
